# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
print("El Zen de Python, por Tim Peters")
print("Bello es mejor que feo.")
print("Explicito es mejor que implicito.")
print("Simple es mejor que complejo.")
print("Complejo es mejor que complicado.")
print("Plano es mejor que anidado.")
print("Disperso es mejor que denso.")
print("La legibilidad cuenta.")
print("Los casos especiales no son lo suficientemente especiales para romper las reglas.")
print("Aunque la practicalidad vence a la pureza.")
print("Los errores nunca deben pasar silenciosamente.")
print("A menos que sean explicitamente silenciados.")
print("En cara a ambiguedad, rehusa la tentacion de adivinar.")
print("Deberia haber una -- y preferiblemente solo una -- forma obvia de hacerlo.")
print("Aunque esa forma puede no ser obvia al inicio a menos que seas holandes.")
print("Ahora es mejor que nunca.")
print("Aunque a veces nunca es mejor que *justo* ahora.")
print("Si la implementacion es dificil de explicar, es una mala idea.")
print("Si la implementacion es facil de explicar, puede ser una buena idea")
print("Los espacios de nombres son una gran idea -- hagamos mas de esos!")
# Out:
# El Zen de Python, por Tim Peters
# Bello es mejor que feo.
# Explicito es mejor que implicito.
# Simple es mejor que complejo.
# Complejo es mejor que complicado.
# Plano es mejor que anidado.
# Disperso es mejor que denso.
# La legibilidad cuenta.
# Los casos especiales no son lo suficientemente especiales para romper las reglas.
# Aunque la practicalidad vence a la pureza.
# Los errores nunca deben pasar silenciosamente.
# A menos que sean explicitamente silenciados.
# En cara a ambiguedad, rehusa la tentacion de adivinar.
# Deberia haber una -- y preferiblemente solo una -- forma obvia de hacerlo.
# Aunque esa forma puede no ser obvia al inicio a menos que seas holandes.
# Ahora es mejor que nunca.
# Aunque a veces nunca es mejor que *justo* ahora.
# Si la implementacion es dificil de explicar, es una mala idea.
# Si la implementacion es facil de explicar, puede ser una buena idea
# Los espacios de nombres son una gran idea -- hagamos mas de esos!

# %%
n = 0
segundos_por_hora = 1 * 3600
# Solicitamos al usuario que ingrese los segundos en una hora
segundos_por_hora = float(input("Ingrese la cantidad de segundos en una hora: "))

# Calculamos los segundos en un día
segundos_por_dia = segundos_por_dia = segundos_por_hora * 24

# Realizamos la división con punto flotante
resultado_division_flotante = resultado1 = segundos_por_dia / segundos_por_hora

# Realizamos la división de enteros
resultado_division_enteros = resultado2 = segundos_por_dia // segundos_por_hora

# Imprimimos los resultados
#print("Segundos en un día (cálculo directo):", segundos_por_dia)
#print("División con punto flotante:", resultado_division_flotante)
#print("División de enteros:", resultado_division_enteros)
