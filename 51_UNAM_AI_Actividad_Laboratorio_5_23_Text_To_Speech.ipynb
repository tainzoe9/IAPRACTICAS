# %% [markdown]
# <a href="https://colab.research.google.com/github/tainzoe9/IAPRACTICAS/blob/main/51_UNAM_AI_Actividad_Laboratorio_5_23_Text_To_Speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# $\Huge \textbf{Universidad Nacional Autónoma de México}$
# $\Huge \textbf{Facultad de Ciencias}$
# <p align="center">
#   <img src="https://www.icat.unam.mx/wp-content/uploads/2021/11/Copia-de-LogoUNAM.-Azul.-Fondo-transparente.png" alt="UNAM" width="200"/>
# </p>
#
# <hr style="height:3px; background-color:#0B6E4F; border:none;"/>
#
#
# $\LARGE \textbf{Inteligencia Artificial}$
#
# $\Large \textit{Laboratorio 5.22}$
#
#
# \begin{array}{rl}
# \textbf{Docente:} & Dra. Jessica Sarahi Méndez Rincón \\[6pt]
# \textbf{Alumna:} & Sotomayor Carrillo Sita Zoe \\[6pt]
# \textbf{Fecha de realización:} & 20/05/2026
# \end{array}
#
# </center>
#
#
#
# ---

# %% [markdown]
# **UNAM y la creadora del presente notebook, no guarda relación alguna con las marcas mencionadas como ejemplo. Las marcas son propiedad de sus titulares conforme a la legislación aplicable, se utilizan con fines académicos y didácticos, por lo que no existen fines de lucro, relación publicitaria o de patrocinio.
#
# ---

# %%
# !pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Downloading pyttsx3-2.99-py3-none-any.whl (32 kB)
# Installing collected packages: pyttsx3
# Successfully installed pyttsx3-2.99

# %%
# !apt-get install -y espeak espeak-ng libespeak-dev alsa-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   espeak-data espeak-ng-data libatopology2 libespeak-ng1 libespeak1
#   libfftw3-single3 libpcaudio0 libportaudio2 libsonic0
# Suggested packages:
#   dialog libfftw3-bin libfftw3-dev
# The following NEW packages will be installed:
#   alsa-utils espeak espeak-data espeak-ng espeak-ng-data libatopology2
#   libespeak-dev libespeak-ng1 libespeak1 libfftw3-single3 libpcaudio0
#   libportaudio2 libsonic0
# 0 upgraded, 13 newly installed, 0 to remove and 1 not upgraded.
# Need to get 8,118 kB of archives.
# After this operation, 20.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libatopology2 amd64 1.2.6.1-1ubuntu1.1 [51.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-single3 amd64 3.3.8-2ubuntu8 [800 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 alsa-utils amd64 1.2.6-1ubuntu1 [1,177 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportaudio2 amd64 19.6.0-1.1 [65.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsonic0 amd64 0.2.0-11build1 [10.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak-data amd64 1.48.15+dfsg-3 [1,085 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak1 amd64 1.48.15+dfsg-3 [156 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak amd64 1.48.15+dfsg-3 [64.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpcaudio0 amd64 1.1-6build2 [8,956 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 espeak-ng-data amd64 1.50+dfsg-10ubuntu0.1 [3,956 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libespeak-ng1 amd64 1.50+dfsg-10ubuntu0.1 [207 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 espeak-ng amd64 1.50+dfsg-10ubuntu0.1 [343 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak-dev amd64 1.48.15+dfsg-3 [193 kB]
# Fetched 8,118 kB in 0s (17.3 MB/s)
# Selecting previously unselected package libatopology2:amd64.
# (Reading database ... 118212 files and directories currently installed.)
# Preparing to unpack .../00-libatopology2_1.2.6.1-1ubuntu1.1_amd64.deb ...
# Unpacking libatopology2:amd64 (1.2.6.1-1ubuntu1.1) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../01-libfftw3-single3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package alsa-utils.
# Preparing to unpack .../02-alsa-utils_1.2.6-1ubuntu1_amd64.deb ...
# Unpacking alsa-utils (1.2.6-1ubuntu1) ...
# Selecting previously unselected package libportaudio2:amd64.
# Preparing to unpack .../03-libportaudio2_19.6.0-1.1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1.1) ...
# Selecting previously unselected package libsonic0:amd64.
# Preparing to unpack .../04-libsonic0_0.2.0-11build1_amd64.deb ...
# Unpacking libsonic0:amd64 (0.2.0-11build1) ...
# Selecting previously unselected package espeak-data:amd64.
# Preparing to unpack .../05-espeak-data_1.48.15+dfsg-3_amd64.deb ...
# Unpacking espeak-data:amd64 (1.48.15+dfsg-3) ...
# Selecting previously unselected package libespeak1:amd64.
# Preparing to unpack .../06-libespeak1_1.48.15+dfsg-3_amd64.deb ...
# Unpacking libespeak1:amd64 (1.48.15+dfsg-3) ...
# Selecting previously unselected package espeak.
# Preparing to unpack .../07-espeak_1.48.15+dfsg-3_amd64.deb ...
# Unpacking espeak (1.48.15+dfsg-3) ...
# Selecting previously unselected package libpcaudio0:amd64.
# Preparing to unpack .../08-libpcaudio0_1.1-6build2_amd64.deb ...
# Unpacking libpcaudio0:amd64 (1.1-6build2) ...
# Selecting previously unselected package espeak-ng-data:amd64.
# Preparing to unpack .../09-espeak-ng-data_1.50+dfsg-10ubuntu0.1_amd64.deb ...
# Unpacking espeak-ng-data:amd64 (1.50+dfsg-10ubuntu0.1) ...
# Selecting previously unselected package libespeak-ng1:amd64.
# Preparing to unpack .../10-libespeak-ng1_1.50+dfsg-10ubuntu0.1_amd64.deb ...
# Unpacking libespeak-ng1:amd64 (1.50+dfsg-10ubuntu0.1) ...
# Selecting previously unselected package espeak-ng.
# Preparing to unpack .../11-espeak-ng_1.50+dfsg-10ubuntu0.1_amd64.deb ...
# Unpacking espeak-ng (1.50+dfsg-10ubuntu0.1) ...
# Selecting previously unselected package libespeak-dev:amd64.
# Preparing to unpack .../12-libespeak-dev_1.48.15+dfsg-3_amd64.deb ...
# Unpacking libespeak-dev:amd64 (1.48.15+dfsg-3) ...
# Setting up libportaudio2:amd64 (19.6.0-1.1) ...
# Setting up libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libpcaudio0:amd64 (1.1-6build2) ...
# Setting up libsonic0:amd64 (0.2.0-11build1) ...
# Setting up espeak-data:amd64 (1.48.15+dfsg-3) ...
# Setting up libatopology2:amd64 (1.2.6.1-1ubuntu1.1) ...
# Setting up espeak-ng-data:amd64 (1.50+dfsg-10ubuntu0.1) ...
# Setting up libespeak1:amd64 (1.48.15+dfsg-3) ...
# Setting up espeak (1.48.15+dfsg-3) ...
# Setting up libespeak-ng1:amd64 (1.50+dfsg-10ubuntu0.1) ...
# Setting up alsa-utils (1.2.6-1ubuntu1) ...
# Setting up espeak-ng (1.50+dfsg-10ubuntu0.1) ...
# Setting up libespeak-dev:amd64 (1.48.15+dfsg-3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link

# %%
# !pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from gTTS) (2.32.4)
# Collecting click<8.2,>=7.1 (from gTTS)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2026.4.22)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: click, gTTS
#   Attempting uninstall: click
#     Found existing installation: click 8.3.3
#     Uninstalling click-8.3.3:
#       Successfully uninstalled click-8.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# typer 0.24.2 requires click>=8.2.1, but you have click 8.1.8 which is incompatible.
# Successfully installed click-8.1.8 gTTS-2.5.4

# %%
from gtts import gTTS
from IPython.display import Audio

# 1. Definir el texto
texto = (
    "Cada que Juan Carlos Iracheta terminaba de dar el reporte del clima, "
    "para despedirse recitaba la frase: Espero que tenga usted un día de intenso calor."
)

# 2. Crear el objeto TTS especificando el idioma en español ('es')
# Puedes usar 'es-us' para acento latino o 'es' para estándar
tts = gTTS(text=texto, lang='es', slow=False)

# 3. Guardar el resultado en un archivo de audio temporal
archivo_audio = 'iracheta_clima.mp3'
tts.save(archivo_audio)

# 4. Mostrar el reproductor de audio nativo en Google Colab
Audio(archivo_audio, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Ejercicio 1: El Traductor y Políglota (Manejo de múltiples idiomas)
#
# gTTS soporta decenas de idiomas. En este ejercicio, configuraremos un diccionario con una misma frase traducida a diferentes idiomas (español, inglés, francés y japonés) y generaremos los audios en un ciclo para comparar cómo suenan las pronunciaciones nativas de Google.

# %%
from gtts import gTTS
from IPython.display import Audio, display

# 1. Definimos un diccionario con el texto y su respectivo código de idioma
frases_multilingues = {
    "Español": {"texto": "Bienvenidos al fascinante mundo de la inteligencia artificial.", "lang": "es"},
    "Inglés": {"texto": "Welcome to the fascinating world of artificial intelligence.", "lang": "en"},
    "Francés": {"texto": "Bienvenue dans le monde fascinante de l'intelligence artificielle.", "lang": "fr"},
    "Japonés": {"texto": "人工知能の魅惑的な世界へようこそ。", "lang": "ja"}
}

# 2. Iteramos sobre el diccionario para generar y mostrar cada audio
print("--- Generando reproducciones multilingües ---")
for idioma, info in frases_multilingues.items():
    # Crear el objeto TTS para el idioma específico
    tts = gTTS(text=info["texto"], lang=info["lang"], slow=False)

    # Nombre de archivo único por idioma
    nombre_archivo = f"audio_{info['lang']}.mp3"
    tts.save(nombre_archivo)

    # Mostramos una etiqueta y el reproductor en la celda
    print(f"\n📢 Idioma: {idioma} ({info['texto']})")
    display(Audio(nombre_archivo, autoplay=False))
# Out:
# --- Generando reproducciones multilingües ---
#
# 📢 Idioma: Español (Bienvenidos al fascinante mundo de la inteligencia artificial.)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Idioma: Inglés (Welcome to the fascinating world of artificial intelligence.)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Idioma: Francés (Bienvenue dans le monde fascinante de l'intelligence artificielle.)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Idioma: Japonés (人工知能の魅惑的な世界へようこそ。)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Ejercicio 2: El Lector de diálogos interactivos (Simulación de una conversación)
#
# En este ejercicio vamos a simular un diálogo interactivo entre dos personajes utilizando variables para automatizar la lectura de un guion. Además, utilizaremos el parámetro slow=True en uno de los personajes para simular que habla de forma más pausada o reflexiva.

# %%
from gtts import gTTS
from IPython.display import Audio, display
import time

# 1. Definimos el guion de la conversación
# Cada elemento es una tupla: (Personaje, Texto, Velocidad_Lenta)
guion = [
    ("Profesor", "Hola a todos. Hoy analizaremos el comportamiento de los algoritmos estocásticos.", False),
    ("Estudiante", "Profesor, ¿podríamos usar un modelo de Markov para predecir el clima como Iracheta?", False),
    ("Profesor", "Excelente pregunta. De hecho, un Modelo Oculto de Markov es perfecto para eso.", True)
    # El profesor habla lento en su última intervención para enfatizar la explicación.
]

# 2. Procesamos el guion y generamos los bloques de audio
print("--- Procesando el diálogo interactivo ---")
for i, (personaje, parlamento, hablar_lento) in enumerate(guion):
    # Generamos la voz (usando acento de EE.UU. en español 'es-us' para variar el tono si se desea)
    tts = gTTS(text=parlamento, lang='es', slow=hablar_lento)

    archivo_dialogo = f"dialogo_{i}.mp3"
    tts.save(archivo_dialogo)

    # Desplegamos el resultado de manera ordenada
    print(f"\n👤 {personaje}: \"{parlamento}\"")
    if hablar_lento:
        print("*(Hablando en modo pausado...)*")
    display(Audio(archivo_dialogo, autoplay=False))
# Out:
# --- Procesando el diálogo interactivo ---
#
# 👤 Profesor: "Hola a todos. Hoy analizaremos el comportamiento de los algoritmos estocásticos."
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 👤 Estudiante: "Profesor, ¿podríamos usar un modelo de Markov para predecir el clima como Iracheta?"
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 👤 Profesor: "Excelente pregunta. De hecho, un Modelo Oculto de Markov es perfecto para eso."
# *(Hablando en modo pausado...)*
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install edge-tts
# Out:
# Collecting edge-tts
#   Downloading edge_tts-7.2.8-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from edge-tts) (3.13.5)
# Requirement already satisfied: certifi>=2023.11.17 in /usr/local/lib/python3.12/dist-packages (from edge-tts) (2026.4.22)
# Requirement already satisfied: tabulate<1.0.0,>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from edge-tts) (0.9.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from edge-tts) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.0->edge-tts) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.8.0->edge-tts) (3.13)
# Downloading edge_tts-7.2.8-py3-none-any.whl (31 kB)
# Installing collected packages: edge-tts
# Successfully installed edge-tts-7.2.8

# %%
import asyncio
import edge_tts
from IPython.display import Audio, display

# 1. Guion con nombres de voces actualizados y verificados
guion = [
    {
        "personaje": "Profesor (Voz Masculina)",
        "texto": "Hola a todos. Hoy analizaremos el comportamiento de los algoritmos estocásticos.",
        "voz": "es-MX-JorgeNeural"  # Voz masculina estándar garantizada
    },
    {
        "personaje": "Estudiante (Voz Femenina)",
        "texto": "Profesor, ¿podríamos usar un modelo de Markov para predecir el clima como Iracheta?",
        "voz": "es-MX-DaliaNeural"  # Voz femenina estándar garantizada
    },
    {
        "personaje": "Profesor (Voz Masculina)",
        "texto": "Excelente pregunta. De hecho, un Modelo Oculto de Markov es perfecto para eso.",
        "voz": "es-MX-JorgeNeural"
    }
]

# 2. Función asíncrona con manejo seguro de flujo
async def generar_dialogo_seguro():
    print("--- Procesando diálogo con voces neuronales de Microsoft ---")
    for i, line in enumerate(guion):
        archivo_salida = f"dialogo_neural_{i}.mp3"

        try:
            # Crear la comunicación con el servicio de Edge
            communicate = edge_tts.Communicate(line["texto"], line["voz"])
            # Guardar de manera asíncrona
            await communicate.save(archivo_salida)

            # Desplegar los resultados en la libreta si el archivo se creó con éxito
            print(f"\n👤 {line['personaje']}: \"{line['texto']}\"")
            display(Audio(archivo_salida, autoplay=False))

        except Exception as err:
            print(f"\n❌ Error al generar la voz para {line['personaje']}: {err}")

# 3. Ejecución directa en Colab
await generar_dialogo_seguro()
# Out:
# --- Procesando diálogo con voces neuronales de Microsoft ---
#
# 👤 Profesor (Voz Masculina): "Hola a todos. Hoy analizaremos el comportamiento de los algoritmos estocásticos."
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 👤 Estudiante (Voz Femenina): "Profesor, ¿podríamos usar un modelo de Markov para predecir el clima como Iracheta?"
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 👤 Profesor (Voz Masculina): "Excelente pregunta. De hecho, un Modelo Oculto de Markov es perfecto para eso."
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Desafío
#
# Escribe el código para que la voz artificial diga el lema de la UNAM en 4 idiomas e intercaladamente voz de hombre y mujer.

# %%
mottos = [
    {
        "language": "Spanish",
        "motto": "Por mi raza hablará el espíritu",
        "lang_code": "es-MX",
        "male_voice": "es-MX-JorgeNeural",
        "female_voice": "es-MX-DaliaNeural"
    },
    {
        "language": "English",
        "motto": "My spirit will speak for my race",
        "lang_code": "en-US",
        "male_voice": "en-US-ChristopherNeural",
        "female_voice": "en-US-AriaNeural"
    },
    {
        "language": "French",
        "motto": "Mon esprit parlera pour ma race",
        "lang_code": "fr-FR",
        "male_voice": "fr-FR-HenriNeural",
        "female_voice": "fr-FR-DeniseNeural"
    },
    {
        "language": "Portuguese",
        "motto": "Meu espírito falará por minha raça",
        "lang_code": "pt-BR",
        "male_voice": "pt-BR-AntonioNeural",
        "female_voice": "pt-BR-FranciscaNeural"
    }
]

print(mottos)
# Out:
# [{'language': 'Spanish', 'motto': 'Por mi raza hablará el espíritu', 'lang_code': 'es-MX', 'male_voice': 'es-MX-JorgeNeural', 'female_voice': 'es-MX-DaliaNeural'}, {'language': 'English', 'motto': 'My spirit will speak for my race', 'lang_code': 'en-US', 'male_voice': 'en-US-ChristopherNeural', 'female_voice': 'en-US-AriaNeural'}, {'language': 'French', 'motto': 'Mon esprit parlera pour ma race', 'lang_code': 'fr-FR', 'male_voice': 'fr-FR-HenriNeural', 'female_voice': 'fr-FR-DeniseNeural'}, {'language': 'Portuguese', 'motto': 'Meu espírito falará por minha raça', 'lang_code': 'pt-BR', 'male_voice': 'pt-BR-AntonioNeural', 'female_voice': 'pt-BR-FranciscaNeural'}]

# %%
import asyncio
import edge_tts
from IPython.display import Audio, display
import time # Import time for sleep

async def generate_multilingual_mottos():
    print("--- Generating multilingual mottos with alternating voices ---")
    for entry in mottos:
        # Generate for male voice
        male_filename = f"motto_{entry['lang_code']}_male.mp3"
        attempts = 0
        max_attempts = 3 # Define max retries
        while attempts < max_attempts:
            try:
                print(f"\n📢 Language: {entry['language']} (Male Voice) - Attempt {attempts + 1}")
                communicate = edge_tts.Communicate(entry['motto'], entry['male_voice'])
                await communicate.save(male_filename)
                display(Audio(male_filename, autoplay=False))
                break # Break if successful
            except Exception as err:
                attempts += 1
                print(f"❌ Error de audio for {entry['language']} (Male Voice): {err}")
                if attempts < max_attempts:
                    print(f"Retrying in 2 seconds...")
                    await asyncio.sleep(2) # Wait before retrying
                else:
                    print(f"⛔ Max attempts reached for {entry['language']} (Male Voice).")

        # Generate for female voice
        female_filename = f"motto_{entry['lang_code']}_female.mp3"
        attempts = 0
        while attempts < max_attempts:
            try:
                print(f"\n📢 Language: {entry['language']} (Female Voice) - Attempt {attempts + 1}")
                communicate = edge_tts.Communicate(entry['motto'], entry['female_voice'])
                await communicate.save(female_filename)
                display(Audio(female_filename, autoplay=False))
                break # Break if successful
            except Exception as err:
                attempts += 1
                print(f"❌ Error de audio for {entry['language']} (Female Voice): {err}")
                if attempts < max_attempts:
                    print(f"Retrying in 2 seconds...")
                    await asyncio.sleep(2) # Wait before retrying
                else:
                    print(f"⛔ Max attempts reached for {entry['language']} (Female Voice).")

    print("\n--- Audio generation complete ---")

# %%
import edge_tts
import asyncio

async def list_available_voices():
    print("Listing available voices (this may take a moment)...")
    try:
        voices = await edge_tts.list_voices()
        for voice in voices:
            print(f"Locale: {voice['Locale']}, Name: {voice['Name']}, Gender: {voice['Gender']}")
    except Exception as e:
        print(f"Error listing voices: {e}")

await list_available_voices()
# Out:
# Listing available voices (this may take a moment)...
# Locale: af-ZA, Name: Microsoft Server Speech Text to Speech Voice (af-ZA, AdriNeural), Gender: Female
# Locale: af-ZA, Name: Microsoft Server Speech Text to Speech Voice (af-ZA, WillemNeural), Gender: Male
# Locale: sq-AL, Name: Microsoft Server Speech Text to Speech Voice (sq-AL, AnilaNeural), Gender: Female
# Locale: sq-AL, Name: Microsoft Server Speech Text to Speech Voice (sq-AL, IlirNeural), Gender: Male
# Locale: am-ET, Name: Microsoft Server Speech Text to Speech Voice (am-ET, AmehaNeural), Gender: Male
# Locale: am-ET, Name: Microsoft Server Speech Text to Speech Voice (am-ET, MekdesNeural), Gender: Female
# Locale: ar-DZ, Name: Microsoft Server Speech Text to Speech Voice (ar-DZ, AminaNeural), Gender: Female
# Locale: ar-DZ, Name: Microsoft Server Speech Text to Speech Voice (ar-DZ, IsmaelNeural), Gender: Male
# Locale: ar-BH, Name: Microsoft Server Speech Text to Speech Voice (ar-BH, AliNeural), Gender: Male
# Locale: ar-BH, Name: Microsoft Server Speech Text to Speech Voice (ar-BH, LailaNeural), Gender: Female
# Locale: ar-EG, Name: Microsoft Server Speech Text to Speech Voice (ar-EG, SalmaNeural), Gender: Female
# Locale: ar-EG, Name: Microsoft Server Speech Text to Speech Voice (ar-EG, ShakirNeural), Gender: Male
# Locale: ar-IQ, Name: Microsoft Server Speech Text to Speech Voice (ar-IQ, BasselNeural), Gender: Male
# Locale: ar-IQ, Name: Microsoft Server Speech Text to Speech Voice (ar-IQ, RanaNeural), Gender: Female
# Locale: ar-JO, Name: Microsoft Server Speech Text to Speech Voice (ar-JO, SanaNeural), Gender: Female
# Locale: ar-JO, Name: Microsoft Server Speech Text to Speech Voice (ar-JO, TaimNeural), Gender: Male
# Locale: ar-KW, Name: Microsoft Server Speech Text to Speech Voice (ar-KW, FahedNeural), Gender: Male
# Locale: ar-KW, Name: Microsoft Server Speech Text to Speech Voice (ar-KW, NouraNeural), Gender: Female
# Locale: ar-LB, Name: Microsoft Server Speech Text to Speech Voice (ar-LB, LaylaNeural), Gender: Female
# Locale: ar-LB, Name: Microsoft Server Speech Text to Speech Voice (ar-LB, RamiNeural), Gender: Male
# Locale: ar-LY, Name: Microsoft Server Speech Text to Speech Voice (ar-LY, ImanNeural), Gender: Female
# Locale: ar-LY, Name: Microsoft Server Speech Text to Speech Voice (ar-LY, OmarNeural), Gender: Male
# Locale: ar-MA, Name: Microsoft Server Speech Text to Speech Voice (ar-MA, JamalNeural), Gender: Male
# Locale: ar-MA, Name: Microsoft Server Speech Text to Speech Voice (ar-MA, MounaNeural), Gender: Female
# Locale: ar-OM, Name: Microsoft Server Speech Text to Speech Voice (ar-OM, AbdullahNeural), Gender: Male
# Locale: ar-OM, Name: Microsoft Server Speech Text to Speech Voice (ar-OM, AyshaNeural), Gender: Female
# Locale: ar-QA, Name: Microsoft Server Speech Text to Speech Voice (ar-QA, AmalNeural), Gender: Female
# Locale: ar-QA, Name: Microsoft Server Speech Text to Speech Voice (ar-QA, MoazNeural), Gender: Male
# Locale: ar-SA, Name: Microsoft Server Speech Text to Speech Voice (ar-SA, HamedNeural), Gender: Male
# Locale: ar-SA, Name: Microsoft Server Speech Text to Speech Voice (ar-SA, ZariyahNeural), Gender: Female
# Locale: ar-SY, Name: Microsoft Server Speech Text to Speech Voice (ar-SY, AmanyNeural), Gender: Female
# Locale: ar-SY, Name: Microsoft Server Speech Text to Speech Voice (ar-SY, LaithNeural), Gender: Male
# Locale: ar-TN, Name: Microsoft Server Speech Text to Speech Voice (ar-TN, HediNeural), Gender: Male
# Locale: ar-TN, Name: Microsoft Server Speech Text to Speech Voice (ar-TN, ReemNeural), Gender: Female
# Locale: ar-AE, Name: Microsoft Server Speech Text to Speech Voice (ar-AE, FatimaNeural), Gender: Female
# Locale: ar-AE, Name: Microsoft Server Speech Text to Speech Voice (ar-AE, HamdanNeural), Gender: Male
# Locale: ar-YE, Name: Microsoft Server Speech Text to Speech Voice (ar-YE, MaryamNeural), Gender: Female
# Locale: ar-YE, Name: Microsoft Server Speech Text to Speech Voice (ar-YE, SalehNeural), Gender: Male
# Locale: az-AZ, Name: Microsoft Server Speech Text to Speech Voice (az-AZ, BabekNeural), Gender: Male
# Locale: az-AZ, Name: Microsoft Server Speech Text to Speech Voice (az-AZ, BanuNeural), Gender: Female
# Locale: bn-BD, Name: Microsoft Server Speech Text to Speech Voice (bn-BD, NabanitaNeural), Gender: Female
# Locale: bn-BD, Name: Microsoft Server Speech Text to Speech Voice (bn-BD, PradeepNeural), Gender: Male
# Locale: bn-IN, Name: Microsoft Server Speech Text to Speech Voice (bn-IN, BashkarNeural), Gender: Male
# Locale: bn-IN, Name: Microsoft Server Speech Text to Speech Voice (bn-IN, TanishaaNeural), Gender: Female
# Locale: bs-BA, Name: Microsoft Server Speech Text to Speech Voice (bs-BA, VesnaNeural), Gender: Female
# Locale: bs-BA, Name: Microsoft Server Speech Text to Speech Voice (bs-BA, GoranNeural), Gender: Male
# Locale: bg-BG, Name: Microsoft Server Speech Text to Speech Voice (bg-BG, BorislavNeural), Gender: Male
# Locale: bg-BG, Name: Microsoft Server Speech Text to Speech Voice (bg-BG, KalinaNeural), Gender: Female
# Locale: my-MM, Name: Microsoft Server Speech Text to Speech Voice (my-MM, NilarNeural), Gender: Female
# Locale: my-MM, Name: Microsoft Server Speech Text to Speech Voice (my-MM, ThihaNeural), Gender: Male
# Locale: ca-ES, Name: Microsoft Server Speech Text to Speech Voice (ca-ES, EnricNeural), Gender: Male
# Locale: ca-ES, Name: Microsoft Server Speech Text to Speech Voice (ca-ES, JoanaNeural), Gender: Female
# Locale: zh-HK, Name: Microsoft Server Speech Text to Speech Voice (zh-HK, HiuGaaiNeural), Gender: Female
# Locale: zh-HK, Name: Microsoft Server Speech Text to Speech Voice (zh-HK, HiuMaanNeural), Gender: Female
# Locale: zh-HK, Name: Microsoft Server Speech Text to Speech Voice (zh-HK, WanLungNeural), Gender: Male
# Locale: zh-CN, Name: Microsoft Server Speech Text to Speech Voice (zh-CN, XiaoxiaoNeural), Gender: Female
# Locale: zh-CN, Name: Microsoft Server Speech Text to Speech Voice (zh-CN, XiaoyiNeural), Gender: Female
# Locale: zh-CN, Name: Microsoft Server Speech Text to Speech Voice (zh-CN, YunjianNeural), Gender: Male
# Locale: zh-CN, Name: Microsoft Server Speech Text to Speech Voice (zh-CN, YunxiNeural), Gender: Male
# Locale: zh-CN, Name: Microsoft Server Speech Text to Speech Voice (zh-CN, YunxiaNeural), Gender: Male
# Locale: zh-CN, Name: Microsoft Server Speech Text to Speech Voice (zh-CN, YunyangNeural), Gender: Male
# Locale: zh-CN-liaoning, Name: Microsoft Server Speech Text to Speech Voice (zh-CN-liaoning, XiaobeiNeural), Gender: Female
# Locale: zh-TW, Name: Microsoft Server Speech Text to Speech Voice (zh-TW, HsiaoChenNeural), Gender: Female
# Locale: zh-TW, Name: Microsoft Server Speech Text to Speech Voice (zh-TW, YunJheNeural), Gender: Male
# Locale: zh-TW, Name: Microsoft Server Speech Text to Speech Voice (zh-TW, HsiaoYuNeural), Gender: Female
# Locale: zh-CN-shaanxi, Name: Microsoft Server Speech Text to Speech Voice (zh-CN-shaanxi, XiaoniNeural), Gender: Female
# Locale: hr-HR, Name: Microsoft Server Speech Text to Speech Voice (hr-HR, GabrijelaNeural), Gender: Female
# Locale: hr-HR, Name: Microsoft Server Speech Text to Speech Voice (hr-HR, SreckoNeural), Gender: Male
# Locale: cs-CZ, Name: Microsoft Server Speech Text to Speech Voice (cs-CZ, AntoninNeural), Gender: Male
# Locale: cs-CZ, Name: Microsoft Server Speech Text to Speech Voice (cs-CZ, VlastaNeural), Gender: Female
# Locale: da-DK, Name: Microsoft Server Speech Text to Speech Voice (da-DK, ChristelNeural), Gender: Female
# Locale: da-DK, Name: Microsoft Server Speech Text to Speech Voice (da-DK, JeppeNeural), Gender: Male
# Locale: nl-BE, Name: Microsoft Server Speech Text to Speech Voice (nl-BE, ArnaudNeural), Gender: Male
# Locale: nl-BE, Name: Microsoft Server Speech Text to Speech Voice (nl-BE, DenaNeural), Gender: Female
# Locale: nl-NL, Name: Microsoft Server Speech Text to Speech Voice (nl-NL, ColetteNeural), Gender: Female
# Locale: nl-NL, Name: Microsoft Server Speech Text to Speech Voice (nl-NL, FennaNeural), Gender: Female
# Locale: nl-NL, Name: Microsoft Server Speech Text to Speech Voice (nl-NL, MaartenNeural), Gender: Male
# Locale: en-AU, Name: Microsoft Server Speech Text to Speech Voice (en-AU, WilliamMultilingualNeural), Gender: Male
# Locale: en-AU, Name: Microsoft Server Speech Text to Speech Voice (en-AU, NatashaNeural), Gender: Female
# Locale: en-CA, Name: Microsoft Server Speech Text to Speech Voice (en-CA, ClaraNeural), Gender: Female
# Locale: en-CA, Name: Microsoft Server Speech Text to Speech Voice (en-CA, LiamNeural), Gender: Male
# Locale: en-HK, Name: Microsoft Server Speech Text to Speech Voice (en-HK, YanNeural), Gender: Female
# Locale: en-HK, Name: Microsoft Server Speech Text to Speech Voice (en-HK, SamNeural), Gender: Male
# Locale: en-IN, Name: Microsoft Server Speech Text to Speech Voice (en-IN, NeerjaExpressiveNeural), Gender: Female
# Locale: en-IN, Name: Microsoft Server Speech Text to Speech Voice (en-IN, NeerjaNeural), Gender: Female
# Locale: en-IN, Name: Microsoft Server Speech Text to Speech Voice (en-IN, PrabhatNeural), Gender: Male
# Locale: en-IE, Name: Microsoft Server Speech Text to Speech Voice (en-IE, ConnorNeural), Gender: Male
# Locale: en-IE, Name: Microsoft Server Speech Text to Speech Voice (en-IE, EmilyNeural), Gender: Female
# Locale: en-KE, Name: Microsoft Server Speech Text to Speech Voice (en-KE, AsiliaNeural), Gender: Female
# Locale: en-KE, Name: Microsoft Server Speech Text to Speech Voice (en-KE, ChilembaNeural), Gender: Male
# Locale: en-NZ, Name: Microsoft Server Speech Text to Speech Voice (en-NZ, MitchellNeural), Gender: Male
# Locale: en-NZ, Name: Microsoft Server Speech Text to Speech Voice (en-NZ, MollyNeural), Gender: Female
# Locale: en-NG, Name: Microsoft Server Speech Text to Speech Voice (en-NG, AbeoNeural), Gender: Male
# Locale: en-NG, Name: Microsoft Server Speech Text to Speech Voice (en-NG, EzinneNeural), Gender: Female
# Locale: en-PH, Name: Microsoft Server Speech Text to Speech Voice (en-PH, JamesNeural), Gender: Male
# Locale: en-PH, Name: Microsoft Server Speech Text to Speech Voice (en-PH, RosaNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, AvaNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, AndrewNeural), Gender: Male
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, EmmaNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, BrianNeural), Gender: Male
# Locale: en-SG, Name: Microsoft Server Speech Text to Speech Voice (en-SG, LunaNeural), Gender: Female
# Locale: en-SG, Name: Microsoft Server Speech Text to Speech Voice (en-SG, WayneNeural), Gender: Male
# Locale: en-ZA, Name: Microsoft Server Speech Text to Speech Voice (en-ZA, LeahNeural), Gender: Female
# Locale: en-ZA, Name: Microsoft Server Speech Text to Speech Voice (en-ZA, LukeNeural), Gender: Male
# Locale: en-TZ, Name: Microsoft Server Speech Text to Speech Voice (en-TZ, ElimuNeural), Gender: Male
# Locale: en-TZ, Name: Microsoft Server Speech Text to Speech Voice (en-TZ, ImaniNeural), Gender: Female
# Locale: en-GB, Name: Microsoft Server Speech Text to Speech Voice (en-GB, LibbyNeural), Gender: Female
# Locale: en-GB, Name: Microsoft Server Speech Text to Speech Voice (en-GB, MaisieNeural), Gender: Female
# Locale: en-GB, Name: Microsoft Server Speech Text to Speech Voice (en-GB, RyanNeural), Gender: Male
# Locale: en-GB, Name: Microsoft Server Speech Text to Speech Voice (en-GB, SoniaNeural), Gender: Female
# Locale: en-GB, Name: Microsoft Server Speech Text to Speech Voice (en-GB, ThomasNeural), Gender: Male
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, AnaNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, AndrewMultilingualNeural), Gender: Male
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, AriaNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, AvaMultilingualNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, BrianMultilingualNeural), Gender: Male
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, ChristopherNeural), Gender: Male
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, EmmaMultilingualNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, EricNeural), Gender: Male
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, GuyNeural), Gender: Male
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, JennyNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, MichelleNeural), Gender: Female
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, RogerNeural), Gender: Male
# Locale: en-US, Name: Microsoft Server Speech Text to Speech Voice (en-US, SteffanNeural), Gender: Male
# Locale: et-EE, Name: Microsoft Server Speech Text to Speech Voice (et-EE, AnuNeural), Gender: Female
# Locale: et-EE, Name: Microsoft Server Speech Text to Speech Voice (et-EE, KertNeural), Gender: Male
# Locale: fil-PH, Name: Microsoft Server Speech Text to Speech Voice (fil-PH, AngeloNeural), Gender: Male
# Locale: fil-PH, Name: Microsoft Server Speech Text to Speech Voice (fil-PH, BlessicaNeural), Gender: Female
# Locale: fi-FI, Name: Microsoft Server Speech Text to Speech Voice (fi-FI, HarriNeural), Gender: Male
# Locale: fi-FI, Name: Microsoft Server Speech Text to Speech Voice (fi-FI, NooraNeural), Gender: Female
# Locale: fr-BE, Name: Microsoft Server Speech Text to Speech Voice (fr-BE, CharlineNeural), Gender: Female
# Locale: fr-BE, Name: Microsoft Server Speech Text to Speech Voice (fr-BE, GerardNeural), Gender: Male
# Locale: fr-CA, Name: Microsoft Server Speech Text to Speech Voice (fr-CA, ThierryNeural), Gender: Male
# Locale: fr-CA, Name: Microsoft Server Speech Text to Speech Voice (fr-CA, AntoineNeural), Gender: Male
# Locale: fr-CA, Name: Microsoft Server Speech Text to Speech Voice (fr-CA, JeanNeural), Gender: Male
# Locale: fr-CA, Name: Microsoft Server Speech Text to Speech Voice (fr-CA, SylvieNeural), Gender: Female
# Locale: fr-FR, Name: Microsoft Server Speech Text to Speech Voice (fr-FR, VivienneMultilingualNeural), Gender: Female
# Locale: fr-FR, Name: Microsoft Server Speech Text to Speech Voice (fr-FR, RemyMultilingualNeural), Gender: Male
# Locale: fr-FR, Name: Microsoft Server Speech Text to Speech Voice (fr-FR, DeniseNeural), Gender: Female
# Locale: fr-FR, Name: Microsoft Server Speech Text to Speech Voice (fr-FR, EloiseNeural), Gender: Female
# Locale: fr-FR, Name: Microsoft Server Speech Text to Speech Voice (fr-FR, HenriNeural), Gender: Male
# Locale: fr-CH, Name: Microsoft Server Speech Text to Speech Voice (fr-CH, ArianeNeural), Gender: Female
# Locale: fr-CH, Name: Microsoft Server Speech Text to Speech Voice (fr-CH, FabriceNeural), Gender: Male
# Locale: gl-ES, Name: Microsoft Server Speech Text to Speech Voice (gl-ES, RoiNeural), Gender: Male
# Locale: gl-ES, Name: Microsoft Server Speech Text to Speech Voice (gl-ES, SabelaNeural), Gender: Female
# Locale: ka-GE, Name: Microsoft Server Speech Text to Speech Voice (ka-GE, EkaNeural), Gender: Female
# Locale: ka-GE, Name: Microsoft Server Speech Text to Speech Voice (ka-GE, GiorgiNeural), Gender: Male
# Locale: de-AT, Name: Microsoft Server Speech Text to Speech Voice (de-AT, IngridNeural), Gender: Female
# Locale: de-AT, Name: Microsoft Server Speech Text to Speech Voice (de-AT, JonasNeural), Gender: Male
# Locale: de-DE, Name: Microsoft Server Speech Text to Speech Voice (de-DE, SeraphinaMultilingualNeural), Gender: Female
# Locale: de-DE, Name: Microsoft Server Speech Text to Speech Voice (de-DE, FlorianMultilingualNeural), Gender: Male
# Locale: de-DE, Name: Microsoft Server Speech Text to Speech Voice (de-DE, AmalaNeural), Gender: Female
# Locale: de-DE, Name: Microsoft Server Speech Text to Speech Voice (de-DE, ConradNeural), Gender: Male
# Locale: de-DE, Name: Microsoft Server Speech Text to Speech Voice (de-DE, KatjaNeural), Gender: Female
# Locale: de-DE, Name: Microsoft Server Speech Text to Speech Voice (de-DE, KillianNeural), Gender: Male
# Locale: de-CH, Name: Microsoft Server Speech Text to Speech Voice (de-CH, JanNeural), Gender: Male
# Locale: de-CH, Name: Microsoft Server Speech Text to Speech Voice (de-CH, LeniNeural), Gender: Female
# Locale: el-GR, Name: Microsoft Server Speech Text to Speech Voice (el-GR, AthinaNeural), Gender: Female
# Locale: el-GR, Name: Microsoft Server Speech Text to Speech Voice (el-GR, NestorasNeural), Gender: Male
# Locale: gu-IN, Name: Microsoft Server Speech Text to Speech Voice (gu-IN, DhwaniNeural), Gender: Female
# Locale: gu-IN, Name: Microsoft Server Speech Text to Speech Voice (gu-IN, NiranjanNeural), Gender: Male
# Locale: he-IL, Name: Microsoft Server Speech Text to Speech Voice (he-IL, AvriNeural), Gender: Male
# Locale: he-IL, Name: Microsoft Server Speech Text to Speech Voice (he-IL, HilaNeural), Gender: Female
# Locale: hi-IN, Name: Microsoft Server Speech Text to Speech Voice (hi-IN, MadhurNeural), Gender: Male
# Locale: hi-IN, Name: Microsoft Server Speech Text to Speech Voice (hi-IN, SwaraNeural), Gender: Female
# Locale: hu-HU, Name: Microsoft Server Speech Text to Speech Voice (hu-HU, NoemiNeural), Gender: Female
# Locale: hu-HU, Name: Microsoft Server Speech Text to Speech Voice (hu-HU, TamasNeural), Gender: Male
# Locale: is-IS, Name: Microsoft Server Speech Text to Speech Voice (is-IS, GudrunNeural), Gender: Female
# Locale: is-IS, Name: Microsoft Server Speech Text to Speech Voice (is-IS, GunnarNeural), Gender: Male
# Locale: id-ID, Name: Microsoft Server Speech Text to Speech Voice (id-ID, ArdiNeural), Gender: Male
# Locale: id-ID, Name: Microsoft Server Speech Text to Speech Voice (id-ID, GadisNeural), Gender: Female
# Locale: iu-Latn-CA, Name: Microsoft Server Speech Text to Speech Voice (iu-Latn-CA, SiqiniqNeural), Gender: Female
# Locale: iu-Latn-CA, Name: Microsoft Server Speech Text to Speech Voice (iu-Latn-CA, TaqqiqNeural), Gender: Male
# Locale: iu-Cans-CA, Name: Microsoft Server Speech Text to Speech Voice (iu-Cans-CA, SiqiniqNeural), Gender: Female
# Locale: iu-Cans-CA, Name: Microsoft Server Speech Text to Speech Voice (iu-Cans-CA, TaqqiqNeural), Gender: Male
# Locale: ga-IE, Name: Microsoft Server Speech Text to Speech Voice (ga-IE, ColmNeural), Gender: Male
# Locale: ga-IE, Name: Microsoft Server Speech Text to Speech Voice (ga-IE, OrlaNeural), Gender: Female
# Locale: it-IT, Name: Microsoft Server Speech Text to Speech Voice (it-IT, GiuseppeMultilingualNeural), Gender: Male
# Locale: it-IT, Name: Microsoft Server Speech Text to Speech Voice (it-IT, DiegoNeural), Gender: Male
# Locale: it-IT, Name: Microsoft Server Speech Text to Speech Voice (it-IT, ElsaNeural), Gender: Female
# Locale: it-IT, Name: Microsoft Server Speech Text to Speech Voice (it-IT, IsabellaNeural), Gender: Female
# Locale: ja-JP, Name: Microsoft Server Speech Text to Speech Voice (ja-JP, KeitaNeural), Gender: Male
# Locale: ja-JP, Name: Microsoft Server Speech Text to Speech Voice (ja-JP, NanamiNeural), Gender: Female
# Locale: jv-ID, Name: Microsoft Server Speech Text to Speech Voice (jv-ID, DimasNeural), Gender: Male
# Locale: jv-ID, Name: Microsoft Server Speech Text to Speech Voice (jv-ID, SitiNeural), Gender: Female
# Locale: kn-IN, Name: Microsoft Server Speech Text to Speech Voice (kn-IN, GaganNeural), Gender: Male
# Locale: kn-IN, Name: Microsoft Server Speech Text to Speech Voice (kn-IN, SapnaNeural), Gender: Female
# Locale: kk-KZ, Name: Microsoft Server Speech Text to Speech Voice (kk-KZ, AigulNeural), Gender: Female
# Locale: kk-KZ, Name: Microsoft Server Speech Text to Speech Voice (kk-KZ, DauletNeural), Gender: Male
# Locale: km-KH, Name: Microsoft Server Speech Text to Speech Voice (km-KH, PisethNeural), Gender: Male
# Locale: km-KH, Name: Microsoft Server Speech Text to Speech Voice (km-KH, SreymomNeural), Gender: Female
# Locale: ko-KR, Name: Microsoft Server Speech Text to Speech Voice (ko-KR, HyunsuMultilingualNeural), Gender: Male
# Locale: ko-KR, Name: Microsoft Server Speech Text to Speech Voice (ko-KR, InJoonNeural), Gender: Male
# Locale: ko-KR, Name: Microsoft Server Speech Text to Speech Voice (ko-KR, SunHiNeural), Gender: Female
# Locale: lo-LA, Name: Microsoft Server Speech Text to Speech Voice (lo-LA, ChanthavongNeural), Gender: Male
# Locale: lo-LA, Name: Microsoft Server Speech Text to Speech Voice (lo-LA, KeomanyNeural), Gender: Female
# Locale: lv-LV, Name: Microsoft Server Speech Text to Speech Voice (lv-LV, EveritaNeural), Gender: Female
# Locale: lv-LV, Name: Microsoft Server Speech Text to Speech Voice (lv-LV, NilsNeural), Gender: Male
# Locale: lt-LT, Name: Microsoft Server Speech Text to Speech Voice (lt-LT, LeonasNeural), Gender: Male
# Locale: lt-LT, Name: Microsoft Server Speech Text to Speech Voice (lt-LT, OnaNeural), Gender: Female
# Locale: mk-MK, Name: Microsoft Server Speech Text to Speech Voice (mk-MK, AleksandarNeural), Gender: Male
# Locale: mk-MK, Name: Microsoft Server Speech Text to Speech Voice (mk-MK, MarijaNeural), Gender: Female
# Locale: ms-MY, Name: Microsoft Server Speech Text to Speech Voice (ms-MY, OsmanNeural), Gender: Male
# Locale: ms-MY, Name: Microsoft Server Speech Text to Speech Voice (ms-MY, YasminNeural), Gender: Female
# Locale: ml-IN, Name: Microsoft Server Speech Text to Speech Voice (ml-IN, MidhunNeural), Gender: Male
# Locale: ml-IN, Name: Microsoft Server Speech Text to Speech Voice (ml-IN, SobhanaNeural), Gender: Female
# Locale: mt-MT, Name: Microsoft Server Speech Text to Speech Voice (mt-MT, GraceNeural), Gender: Female
# Locale: mt-MT, Name: Microsoft Server Speech Text to Speech Voice (mt-MT, JosephNeural), Gender: Male
# Locale: mr-IN, Name: Microsoft Server Speech Text to Speech Voice (mr-IN, AarohiNeural), Gender: Female
# Locale: mr-IN, Name: Microsoft Server Speech Text to Speech Voice (mr-IN, ManoharNeural), Gender: Male
# Locale: mn-MN, Name: Microsoft Server Speech Text to Speech Voice (mn-MN, BataaNeural), Gender: Male
# Locale: mn-MN, Name: Microsoft Server Speech Text to Speech Voice (mn-MN, YesuiNeural), Gender: Female
# Locale: ne-NP, Name: Microsoft Server Speech Text to Speech Voice (ne-NP, HemkalaNeural), Gender: Female
# Locale: ne-NP, Name: Microsoft Server Speech Text to Speech Voice (ne-NP, SagarNeural), Gender: Male
# Locale: nb-NO, Name: Microsoft Server Speech Text to Speech Voice (nb-NO, FinnNeural), Gender: Male
# Locale: nb-NO, Name: Microsoft Server Speech Text to Speech Voice (nb-NO, PernilleNeural), Gender: Female
# Locale: ps-AF, Name: Microsoft Server Speech Text to Speech Voice (ps-AF, GulNawazNeural), Gender: Male
# Locale: ps-AF, Name: Microsoft Server Speech Text to Speech Voice (ps-AF, LatifaNeural), Gender: Female
# Locale: fa-IR, Name: Microsoft Server Speech Text to Speech Voice (fa-IR, DilaraNeural), Gender: Female
# Locale: fa-IR, Name: Microsoft Server Speech Text to Speech Voice (fa-IR, FaridNeural), Gender: Male
# Locale: pl-PL, Name: Microsoft Server Speech Text to Speech Voice (pl-PL, MarekNeural), Gender: Male
# Locale: pl-PL, Name: Microsoft Server Speech Text to Speech Voice (pl-PL, ZofiaNeural), Gender: Female
# Locale: pt-BR, Name: Microsoft Server Speech Text to Speech Voice (pt-BR, ThalitaMultilingualNeural), Gender: Female
# Locale: pt-BR, Name: Microsoft Server Speech Text to Speech Voice (pt-BR, AntonioNeural), Gender: Male
# Locale: pt-BR, Name: Microsoft Server Speech Text to Speech Voice (pt-BR, FranciscaNeural), Gender: Female
# Locale: pt-PT, Name: Microsoft Server Speech Text to Speech Voice (pt-PT, DuarteNeural), Gender: Male
# Locale: pt-PT, Name: Microsoft Server Speech Text to Speech Voice (pt-PT, RaquelNeural), Gender: Female
# Locale: ro-RO, Name: Microsoft Server Speech Text to Speech Voice (ro-RO, AlinaNeural), Gender: Female
# Locale: ro-RO, Name: Microsoft Server Speech Text to Speech Voice (ro-RO, EmilNeural), Gender: Male
# Locale: ru-RU, Name: Microsoft Server Speech Text to Speech Voice (ru-RU, DmitryNeural), Gender: Male
# Locale: ru-RU, Name: Microsoft Server Speech Text to Speech Voice (ru-RU, SvetlanaNeural), Gender: Female
# Locale: sr-RS, Name: Microsoft Server Speech Text to Speech Voice (sr-RS, NicholasNeural), Gender: Male
# Locale: sr-RS, Name: Microsoft Server Speech Text to Speech Voice (sr-RS, SophieNeural), Gender: Female
# Locale: si-LK, Name: Microsoft Server Speech Text to Speech Voice (si-LK, SameeraNeural), Gender: Male
# Locale: si-LK, Name: Microsoft Server Speech Text to Speech Voice (si-LK, ThiliniNeural), Gender: Female
# Locale: sk-SK, Name: Microsoft Server Speech Text to Speech Voice (sk-SK, LukasNeural), Gender: Male
# Locale: sk-SK, Name: Microsoft Server Speech Text to Speech Voice (sk-SK, ViktoriaNeural), Gender: Female
# Locale: sl-SI, Name: Microsoft Server Speech Text to Speech Voice (sl-SI, PetraNeural), Gender: Female
# Locale: sl-SI, Name: Microsoft Server Speech Text to Speech Voice (sl-SI, RokNeural), Gender: Male
# Locale: so-SO, Name: Microsoft Server Speech Text to Speech Voice (so-SO, MuuseNeural), Gender: Male
# Locale: so-SO, Name: Microsoft Server Speech Text to Speech Voice (so-SO, UbaxNeural), Gender: Female
# Locale: es-AR, Name: Microsoft Server Speech Text to Speech Voice (es-AR, ElenaNeural), Gender: Female
# Locale: es-AR, Name: Microsoft Server Speech Text to Speech Voice (es-AR, TomasNeural), Gender: Male
# Locale: es-BO, Name: Microsoft Server Speech Text to Speech Voice (es-BO, MarceloNeural), Gender: Male
# Locale: es-BO, Name: Microsoft Server Speech Text to Speech Voice (es-BO, SofiaNeural), Gender: Female
# Locale: es-CL, Name: Microsoft Server Speech Text to Speech Voice (es-CL, CatalinaNeural), Gender: Female
# Locale: es-CL, Name: Microsoft Server Speech Text to Speech Voice (es-CL, LorenzoNeural), Gender: Male
# Locale: es-CO, Name: Microsoft Server Speech Text to Speech Voice (es-CO, GonzaloNeural), Gender: Male
# Locale: es-CO, Name: Microsoft Server Speech Text to Speech Voice (es-CO, SalomeNeural), Gender: Female
# Locale: es-ES, Name: Microsoft Server Speech Text to Speech Voice (es-ES, XimenaNeural), Gender: Female
# Locale: es-CR, Name: Microsoft Server Speech Text to Speech Voice (es-CR, JuanNeural), Gender: Male
# Locale: es-CR, Name: Microsoft Server Speech Text to Speech Voice (es-CR, MariaNeural), Gender: Female
# Locale: es-CU, Name: Microsoft Server Speech Text to Speech Voice (es-CU, BelkysNeural), Gender: Female
# Locale: es-CU, Name: Microsoft Server Speech Text to Speech Voice (es-CU, ManuelNeural), Gender: Male
# Locale: es-DO, Name: Microsoft Server Speech Text to Speech Voice (es-DO, EmilioNeural), Gender: Male
# Locale: es-DO, Name: Microsoft Server Speech Text to Speech Voice (es-DO, RamonaNeural), Gender: Female
# Locale: es-EC, Name: Microsoft Server Speech Text to Speech Voice (es-EC, AndreaNeural), Gender: Female
# Locale: es-EC, Name: Microsoft Server Speech Text to Speech Voice (es-EC, LuisNeural), Gender: Male
# Locale: es-SV, Name: Microsoft Server Speech Text to Speech Voice (es-SV, LorenaNeural), Gender: Female
# Locale: es-SV, Name: Microsoft Server Speech Text to Speech Voice (es-SV, RodrigoNeural), Gender: Male
# Locale: es-GQ, Name: Microsoft Server Speech Text to Speech Voice (es-GQ, JavierNeural), Gender: Male
# Locale: es-GQ, Name: Microsoft Server Speech Text to Speech Voice (es-GQ, TeresaNeural), Gender: Female
# Locale: es-GT, Name: Microsoft Server Speech Text to Speech Voice (es-GT, AndresNeural), Gender: Male
# Locale: es-GT, Name: Microsoft Server Speech Text to Speech Voice (es-GT, MartaNeural), Gender: Female
# Locale: es-HN, Name: Microsoft Server Speech Text to Speech Voice (es-HN, CarlosNeural), Gender: Male
# Locale: es-HN, Name: Microsoft Server Speech Text to Speech Voice (es-HN, KarlaNeural), Gender: Female
# Locale: es-MX, Name: Microsoft Server Speech Text to Speech Voice (es-MX, DaliaNeural), Gender: Female
# Locale: es-MX, Name: Microsoft Server Speech Text to Speech Voice (es-MX, JorgeNeural), Gender: Male
# Locale: es-NI, Name: Microsoft Server Speech Text to Speech Voice (es-NI, FedericoNeural), Gender: Male
# Locale: es-NI, Name: Microsoft Server Speech Text to Speech Voice (es-NI, YolandaNeural), Gender: Female
# Locale: es-PA, Name: Microsoft Server Speech Text to Speech Voice (es-PA, MargaritaNeural), Gender: Female
# Locale: es-PA, Name: Microsoft Server Speech Text to Speech Voice (es-PA, RobertoNeural), Gender: Male
# Locale: es-PY, Name: Microsoft Server Speech Text to Speech Voice (es-PY, MarioNeural), Gender: Male
# Locale: es-PY, Name: Microsoft Server Speech Text to Speech Voice (es-PY, TaniaNeural), Gender: Female
# Locale: es-PE, Name: Microsoft Server Speech Text to Speech Voice (es-PE, AlexNeural), Gender: Male
# Locale: es-PE, Name: Microsoft Server Speech Text to Speech Voice (es-PE, CamilaNeural), Gender: Female
# Locale: es-PR, Name: Microsoft Server Speech Text to Speech Voice (es-PR, KarinaNeural), Gender: Female
# Locale: es-PR, Name: Microsoft Server Speech Text to Speech Voice (es-PR, VictorNeural), Gender: Male
# Locale: es-ES, Name: Microsoft Server Speech Text to Speech Voice (es-ES, AlvaroNeural), Gender: Male
# Locale: es-ES, Name: Microsoft Server Speech Text to Speech Voice (es-ES, ElviraNeural), Gender: Female
# Locale: es-US, Name: Microsoft Server Speech Text to Speech Voice (es-US, AlonsoNeural), Gender: Male
# Locale: es-US, Name: Microsoft Server Speech Text to Speech Voice (es-US, PalomaNeural), Gender: Female
# Locale: es-UY, Name: Microsoft Server Speech Text to Speech Voice (es-UY, MateoNeural), Gender: Male
# Locale: es-UY, Name: Microsoft Server Speech Text to Speech Voice (es-UY, ValentinaNeural), Gender: Female
# Locale: es-VE, Name: Microsoft Server Speech Text to Speech Voice (es-VE, PaolaNeural), Gender: Female
# Locale: es-VE, Name: Microsoft Server Speech Text to Speech Voice (es-VE, SebastianNeural), Gender: Male
# Locale: su-ID, Name: Microsoft Server Speech Text to Speech Voice (su-ID, JajangNeural), Gender: Male
# Locale: su-ID, Name: Microsoft Server Speech Text to Speech Voice (su-ID, TutiNeural), Gender: Female
# Locale: sw-KE, Name: Microsoft Server Speech Text to Speech Voice (sw-KE, RafikiNeural), Gender: Male
# Locale: sw-KE, Name: Microsoft Server Speech Text to Speech Voice (sw-KE, ZuriNeural), Gender: Female
# Locale: sw-TZ, Name: Microsoft Server Speech Text to Speech Voice (sw-TZ, DaudiNeural), Gender: Male
# Locale: sw-TZ, Name: Microsoft Server Speech Text to Speech Voice (sw-TZ, RehemaNeural), Gender: Female
# Locale: sv-SE, Name: Microsoft Server Speech Text to Speech Voice (sv-SE, MattiasNeural), Gender: Male
# Locale: sv-SE, Name: Microsoft Server Speech Text to Speech Voice (sv-SE, SofieNeural), Gender: Female
# Locale: ta-IN, Name: Microsoft Server Speech Text to Speech Voice (ta-IN, PallaviNeural), Gender: Female
# Locale: ta-IN, Name: Microsoft Server Speech Text to Speech Voice (ta-IN, ValluvarNeural), Gender: Male
# Locale: ta-MY, Name: Microsoft Server Speech Text to Speech Voice (ta-MY, KaniNeural), Gender: Female
# Locale: ta-MY, Name: Microsoft Server Speech Text to Speech Voice (ta-MY, SuryaNeural), Gender: Male
# Locale: ta-SG, Name: Microsoft Server Speech Text to Speech Voice (ta-SG, AnbuNeural), Gender: Male
# Locale: ta-SG, Name: Microsoft Server Speech Text to Speech Voice (ta-SG, VenbaNeural), Gender: Female
# Locale: ta-LK, Name: Microsoft Server Speech Text to Speech Voice (ta-LK, KumarNeural), Gender: Male
# Locale: ta-LK, Name: Microsoft Server Speech Text to Speech Voice (ta-LK, SaranyaNeural), Gender: Female
# Locale: te-IN, Name: Microsoft Server Speech Text to Speech Voice (te-IN, MohanNeural), Gender: Male
# Locale: te-IN, Name: Microsoft Server Speech Text to Speech Voice (te-IN, ShrutiNeural), Gender: Female
# Locale: th-TH, Name: Microsoft Server Speech Text to Speech Voice (th-TH, NiwatNeural), Gender: Male
# Locale: th-TH, Name: Microsoft Server Speech Text to Speech Voice (th-TH, PremwadeeNeural), Gender: Female
# Locale: tr-TR, Name: Microsoft Server Speech Text to Speech Voice (tr-TR, EmelNeural), Gender: Female
# Locale: tr-TR, Name: Microsoft Server Speech Text to Speech Voice (tr-TR, AhmetNeural), Gender: Male
# Locale: uk-UA, Name: Microsoft Server Speech Text to Speech Voice (uk-UA, OstapNeural), Gender: Male
# Locale: uk-UA, Name: Microsoft Server Speech Text to Speech Voice (uk-UA, PolinaNeural), Gender: Female
# Locale: ur-IN, Name: Microsoft Server Speech Text to Speech Voice (ur-IN, GulNeural), Gender: Female
# Locale: ur-IN, Name: Microsoft Server Speech Text to Speech Voice (ur-IN, SalmanNeural), Gender: Male
# Locale: ur-PK, Name: Microsoft Server Speech Text to Speech Voice (ur-PK, AsadNeural), Gender: Male
# Locale: ur-PK, Name: Microsoft Server Speech Text to Speech Voice (ur-PK, UzmaNeural), Gender: Female
# Locale: uz-UZ, Name: Microsoft Server Speech Text to Speech Voice (uz-UZ, MadinaNeural), Gender: Female
# Locale: uz-UZ, Name: Microsoft Server Speech Text to Speech Voice (uz-UZ, SardorNeural), Gender: Male
# Locale: vi-VN, Name: Microsoft Server Speech Text to Speech Voice (vi-VN, HoaiMyNeural), Gender: Female
# Locale: vi-VN, Name: Microsoft Server Speech Text to Speech Voice (vi-VN, NamMinhNeural), Gender: Male
# Locale: cy-GB, Name: Microsoft Server Speech Text to Speech Voice (cy-GB, AledNeural), Gender: Male
# Locale: cy-GB, Name: Microsoft Server Speech Text to Speech Voice (cy-GB, NiaNeural), Gender: Female
# Locale: zu-ZA, Name: Microsoft Server Speech Text to Speech Voice (zu-ZA, ThandoNeural), Gender: Female
# Locale: zu-ZA, Name: Microsoft Server Speech Text to Speech Voice (zu-ZA, ThembaNeural), Gender: Male
# /usr/lib/python3.12/json/decoder.py:354: RuntimeWarning: coroutine 'generate_multilingual_mottos' was never awaited
#   obj, end = self.scan_once(s, idx)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
await generate_multilingual_mottos()
# Out:
# --- Generating multilingual mottos with alternating voices ---
#
# 📢 Language: Spanish (Male Voice) - Attempt 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Language: Spanish (Female Voice) - Attempt 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Language: English (Male Voice) - Attempt 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Language: English (Female Voice) - Attempt 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Language: French (Male Voice) - Attempt 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Language: French (Female Voice) - Attempt 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Language: Portuguese (Male Voice) - Attempt 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 📢 Language: Portuguese (Female Voice) - Attempt 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# --- Audio generation complete ---

# %% [markdown]
# #Conclusion

# %% [markdown]
# ## Conclusión General
#
# Esta práctica ha explorado el  campo de la síntesis de voz, demostrando cómo las herramientas modernas de Texto a Voz (TTS) pueden transformar texto escrito en habla audible. A través del uso de librerías como `gTTS` y `edge_tts`, hemos generado audios en múltiples idiomas y con diferentes voces, con posibilidades para aplicaciones interactivas y multilingües.
#
# * Se confirmó la capacidad de las tecnologías TTS para manejar diversos idiomas y acentos, permitiendo la comunicación global.
# * La posibilidad de elegir entre voces masculinas y femeninas, y ajustar parámetros como la velocidad, resalta la capacidad de personalización para enriquecer la experiencia auditiva o simular diálogos.
# * La integración de `edge_tts` ilustró la importancia de la programación asíncrona (`asyncio`) para manejar eficientemente operaciones que interactúan con servicios externos, un patrón común en el desarrollo de aplicaciones modernas.
# *  A pesar de los avances, se observaron intermitencias y errores en la generación de audio con `edge_tts` para ciertos idiomas. Esto subraya que, si bien la tecnología es potente, la fiabilidad de los servicios externos y la calidad de la conexión pueden impactar la consistencia de los resultados. La implementación de mecanismos de reintento es una estrategia útil, pero no siempre resuelve problemas subyacentes del servicio o de red.
#
#
# La experimentación con TTS revela el gran potencial para crear experiencias de usuario más accesibles e inmersivas. Desde asistentes virtuales y sistemas educativos hasta herramientas de accesibilidad, la síntesis de voz continúa evolucionando, prometiendo soluciones cada vez más naturales y robustas. Es fundamental seguir explorando las capacidades y limitaciones de estas tecnologías para su aplicación efectiva en diversos contextos.

# %% [markdown]
# <hr/>
# <footer style="text-align:center; font-size:12px; color:gray;">
# © 2026 UNAM Facultado de Ciencias – Todos los derechos reservados
#
# </footer>
